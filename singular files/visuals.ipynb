# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentDepressionDataset.csv')

# %%
df.sample(5)
# Out:
#           id  Gender   Age      City Profession  Academic Pressure  \
# 12073  60944  Female  28.0  Vadodara    Student                2.0
# 17437  88214  Female  28.0    Kalyan    Student                1.0
# 14114  71397  Female  33.0    Meerut    Student                5.0
# 8065   40654    Male  31.0   Kolkata    Student                5.0
# 12897  65294    Male  34.0    Indore    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 12073            0.0  6.75                 5.0               0.0
# 17437            0.0  9.85                 5.0               0.0
# 14114            0.0  6.53                 3.0               0.0
# 8065             0.0  6.28                 1.0               0.0
# 12897            0.0  8.96                 2.0               0.0
#
#           Sleep Duration Dietary Habits   Degree  \
# 12073          5-6 hours      Unhealthy       MD
# 17437          7-8 hours        Healthy  M.Pharm
# ...

# %%
# notes

# show visual for financcial stress missing values
# show visual for financial stress after filling missing values to remove the values with less appearance
# show visual for proffession, job satisfaction, and work pressure so that can remove them 
# show visuals for sleep,diet and degree to remove value others
# show visual for srudy satisfaction to remove value which is zero 
# show visual for age to prove too many values appearing less times
# show visual for city to remove values with less appearance
# show visual to prove most of the degrees can be binned 
# show correlation matrix to prove and  removed

# %%
# visual for missing value of Financial_Stress

financialstresscount=df['Financial Stress'].value_counts()

# plot

plt.bar(financialstresscount.index,financialstresscount)
plt.xlabel('FEATURES')
plt.ylabel('count of FC values')
plt.title('FC Value Count')
plt.show()
