# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df = pd.read_csv('StudentDepressionDataset.csv')

# %%
df.sample(5)
# Out:
#           id  Gender   Age     City Profession  Academic Pressure  \
# 16018  80991  Female  20.0  Kolkata    Student                2.0
# 7270   36594    Male  23.0  Kolkata    Student                3.0
# 3672   18420    Male  18.0   Nashik    Student                4.0
# 15211  76688  Female  24.0    Thane    Student                5.0
# 10496  53208  Female  20.0   Kanpur    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 16018            0.0  5.74                 5.0               0.0
# 7270             0.0  7.45                 2.0               0.0
# 3672             0.0  7.47                 3.0               0.0
# 15211            0.0  6.75                 4.0               0.0
# 10496            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 16018          7-8 hours      Unhealthy  Class 12
# 7270           7-8 hours       Moderate       BSc
# 3672   More than 8 hours      Unhealthy    Others
# 15211          5-6 hours      Unhealthy    B.Arch
# 10496          7-8 hours      Unhealthy  Class 12
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 16018                                   Yes               2.0
# 7270                                    Yes               8.0
# 3672                                    Yes              11.0
# 15211                                   Yes              10.0
# 10496                                   Yes              12.0
#
#        Financial Stress Family History of Mental Illness  Depression
# 16018               3.0                               No           1
# 7270                3.0                               No           1
# 3672                4.0                               No           1
# 15211               4.0                              Yes           1
# 10496               1.0                               No           1

# %%
# notes

# show visual for financcial stress missing values
# show visual for financial stress after filling missing values to remove the values with less appearance
# show visual for proffession, job satisfaction, and work pressure so that can remove them 
# show visuals for sleep,diet and degree to remove value others
# show visual for srudy satisfaction to remove value which is zero 
# show visual for age to prove too many values appearing less times
# show visual for city to remove values with less appearance
# show visual to prove most of the degrees can be binned 
# show correlation matrix to prove and  removed
